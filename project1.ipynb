# %% [markdown]
# <a href="https://colab.research.google.com/github/chotu259/Bhargavi/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# -------------- Real Project Time -------------

# %% [markdown]
# Use tensorflow.keras library for models. And you are free to use chatgpt here at this stage - Yayyyyyyyy\
# Use it where you need help, not to complete the assignment lol

# %%
#import libraries
import librosa
import pandas as pd
from IPython.display import Audio
import os
import io
import numpy as np
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# path="/content/drive/MyDrive/speech/Actor_02/03-01-01-01-01-01-02.wav"
# list_of_features=['mfcc', 'chroma','melspectogram'];
# features=extract_features(path, list_of_features)
# features=np.array(features)
# print(features.shape)

# %% [markdown]
# Define a function to extract features from the given filename. You will have to use librosa library for this. You can vary the features however you like. The preferred features are mfcc, chroma and melspectogram.

# %% [markdown]
# here we take mean of feature  because the features extracted from librosa are of varying lengths due to differences in the audio file durations and the nature of the features themselves

# %%
def extract_features(filename, list_of_features):
  features=[]
  audio,sample_rate=librosa.load(filename)
  for feature in list_of_features:
        if feature == 'mfcc':
            mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=13)
            mfccs_mean = np.mean(mfccs.T, axis=0)
            #print("mfcc",np.shape(mfccs_mean))
            features.append(mfccs_mean)


        elif feature == 'chroma':
            chroma = librosa.feature.chroma_stft(y=audio, sr=sample_rate)
            chroma_mean = np.mean(chroma.T, axis=0)
            #print("chroma",np.shape(chroma_mean))
            features.append(chroma_mean)

# feature == 'melspectrogram':
        else:
            mel_spec = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_fft=2048, hop_length=512)
            mel_spec_mean = np.mean(mel_spec.T, axis=0)
            #print("mel",np.shape(mel_spec_mean ))
            features.append(mel_spec_mean)


  return np.hstack(features)

# %% [markdown]
# Now, load the data from the database.
#
# You can find the database from https://zenodo.org/records/1188976#.XsAXemgzaUk
#
# You need to only download the audio files and not the video files. Also, read up on the naming convention of the files from the webpage.

# %% [markdown]
#  **filename consists fo 7 numbers
# Filename identifiers**
#
# Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# Vocal channel (01 = speech, 02 = song).
#
# Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).

# %%
from IPython.display import Audio
import os
import librosa

def load_audio_files(folder_lists):
    audio_files = []
    for path in folder_lists:
      for filename in os.listdir(path):
        #print(path)
        if filename.endswith('.wav'):
          audio_files.append(os.path.join(path, filename))
    return audio_files
def extract_label(filename):
  names=filename.split('-')
  return int(names[2]);
def load():
   folder_lists=[]
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_01")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_02")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_03")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_04")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_05")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_06")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_07")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_08")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_09")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_10")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_11")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_12")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_13")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_15")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_166")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_177")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_144")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_19")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_20")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_21")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_22")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_23")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_24")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_01")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_02")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_03")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_04")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_05")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_06")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_07")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_08")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_09")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_10")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_11")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_12")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_13")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_14")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_15")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_16")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_17")
   folder_lists.append("/content/drive/MyDrive/datasets/Actor_18")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_19")
   folder_lists.append("/content/drive/MyDrive/speech/Actor_20")
   folder_lists.append ("/content/drive/MyDrive/speech/Actor_21")
   folder_lists.append ("/content/drive/MyDrive/speech/Actor_22")
   folder_lists.append ("/content/drive/MyDrive/speech/Actor_23")
   folder_lists.append ("/content/drive/MyDrive/speech/Actor_24")
   audio_files = load_audio_files(folder_lists)
   #file_data, sample_rate = librosa.load(audio_files[0], sr=None)
   #Audio(data=file_data, rate=sample_rate)
   list_of_features=['mfcc', 'chroma','melspectogram'];
   features=[]
   labels=[]
   for files in   audio_files:
     files_features=extract_features(files, list_of_features)
     features.append(files_features)
     labels.append(extract_label(files))
   audio_files =np.array(audio_files)
   print( audio_files)
   features=np.array(features)
   print("Features shape:", features.shape)
   print("Labels shape:", labels.shape)
   print(features)
   labels=np.array(labels)
   return features,labels

# %% [markdown]
# Use the load_data function to load data and split the data using the
#
#
# train_test_split function.

# %%
#split the dataset into training and testing data with testing data = 0.2 of total data
from sklearn.model_selection import train_test_split
test_size=0.2
features,labels=load()
label_encoder = LabelEncoder()
labels=label_encoder.fit_transform(labels)
labels=to_categorical(labels)
print("Encoded labels shape:", labels.shape)
x_train,x_test,y_train,y_test = train_test_split(features,labels,test_size=test_size,random_state=20)
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# ['/content/drive/MyDrive/datasets/Actor_01/03-01-02-02-01-02-01.wav'
#  '/content/drive/MyDrive/datasets/Actor_01/03-01-02-01-01-02-01.wav'
#  '/content/drive/MyDrive/datasets/Actor_01/03-01-01-01-02-01-01.wav' ...
#  '/content/drive/MyDrive/speech/Actor_24/03-01-08-01-01-01-24.wav'
#  '/content/drive/MyDrive/speech/Actor_24/03-01-07-02-02-02-24.wav'
#  '/content/drive/MyDrive/speech/Actor_24/03-01-08-02-01-01-24.wav']
# features  (2432, 153)
# [[-6.9782233e+02  6.7339592e+01 -4.4955251e-01 ...  1.4704951e-05
#    8.5420779e-06  3.9772033e-07]
#  [-7.0735822e+02  6.6736458e+01  2.2534895e+00 ...  7.4168097e-06
#    3.7060952e-06  3.1081058e-07]
#  [-6.9158789e+02  5.8024662e+01  1.5946500e-01 ...  2.4245850e-05
#    1.3441520e-05  1.1197559e-06]
#  ...
#  [-6.7937347e+02  3.0277012e+01 -2.7324450e+00 ...  1.1337102e-04
#    1.3365665e-04  1.2989140e-05]
#  [-5.1557495e+02  2.6657829e+01 -1.7701347e+01 ...  1.4873437e-03
#    8.3248876e-04  4.4799886e-05]
#  [-5.3246722e+02  3.7716980e+01 -1.4932143e+01 ...  6.3396955e-04
#    3.0358645e-04  3.9353912e-05]]
# Encoded labels shape: (2432, 8)
# x_train shape: (1945, 153)
# y_train shape: (1945, 8)
# x_test shape: (487, 153)
# y_test shape: (487, 8)

# %% [markdown]
# Now you need to define the model for this computation.
# For this, we will use simple neural network for this.\
# The model will have a hidden layer of 300 nodes and an output layer of [number of emotions] nodes.\
# You have to use relu as activation function for the hidden layer and softmax for the output layer.\
# Keep the loss categorical-crossentropy, optimizer as adam and accuracy as metric.\
# You can use batch-size as 256 and epochs as 300, but it is left upto you :)

# %% [markdown]
# from tensorflow.keras.callbacks import EarlyStopping
# early_stopping = EarlyStopping(
#     monitor='val_loss',  # Metric to monitor (could also be 'val_accuracy')
#     patience=150,         # Number of epochs with no improvement after which training will be stopped
#     verbose=1,           # Print messages about early stopping to the console
#     restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored quantity
# )

# %%
#define the model.
#from tensorflow.keras.optimizers import Adam
#optimizer = Adam(learning_rate=learning_rate)
model = Sequential()
model.add(Dense(units=300, input_shape=(153,),activation='sigmoid'))
model.add(Dense(units=8,activation='softmax'))
model.compile( optimizer='Adam', loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 300)               46200
#
#  dense_17 (Dense)            (None, 8)                 2408
#
# =================================================================
# Total params: 48608 (189.88 KB)
# Trainable params: 48608 (189.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Now everything is easy-peezy. Just fit the model on training data as you usually do, predict for the testing data, print the accuracy. Hehe

# %% [markdown]
# #fit the model on training data with validation split of 0.2
# history = model.fit(
#     x_train, y_train,
#     epochs=500,
#     batch_size=256,
#     validation_split=0.2,
#     callbacks=[early_stopping]  # Pass the EarlyStopping callback to the callbacks parameter
# )
# #model.fit(x_train,y_train,epochs=1000,batch_size=256,validation_split=0.2)
# train_predict=model.predict(x_train)
# test_predict=model.predict(x_test)

# %% [markdown]
# monitor: Metric to be monitored. Typically 'val_loss' for minimizing validation loss.
# patience: Number of epochs with no improvement after which training will be stopped.
# verbose: Verbosity mode. 1 for detailed messages.
# restore_best_weights: Whether to restore model weights from the epoch with the best value of the monitored metric.

# %%
from  tensorflow.keras.callbacks import EarlyStopping
earlystopping=EarlyStopping(
    monitor="val_loss",
    min_delta=0,
    patience=100,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0,
)
history = model.fit(
    x_train, y_train,
    epochs=800,
    batch_size=256,
    validation_split=0.2,
    callbacks=[early_stopping]  # Pass the EarlyStopping callback to the callbacks parameter
)
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
# Out:
# Epoch 1/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3160 - accuracy: 0.9145 - val_loss: 1.0857 - val_accuracy: 0.6530
# Epoch 2/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3258 - accuracy: 0.9081 - val_loss: 1.0723 - val_accuracy: 0.6710
# Epoch 3/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3152 - accuracy: 0.9184 - val_loss: 1.0689 - val_accuracy: 0.6787
# Epoch 4/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3048 - accuracy: 0.9216 - val_loss: 1.0584 - val_accuracy: 0.6761
# Epoch 5/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3123 - accuracy: 0.9165 - val_loss: 1.0564 - val_accuracy: 0.6684
# Epoch 6/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3080 - accuracy: 0.9158 - val_loss: 1.0444 - val_accuracy: 0.6504
# Epoch 7/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2983 - accuracy: 0.9274 - val_loss: 1.0591 - val_accuracy: 0.6812
# Epoch 8/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2943 - accuracy: 0.9261 - val_loss: 1.0584 - val_accuracy: 0.6684
# Epoch 9/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2986 - accuracy: 0.9287 - val_loss: 1.0695 - val_accuracy: 0.6864
# Epoch 10/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3126 - accuracy: 0.9222 - val_loss: 1.1011 - val_accuracy: 0.6889
# Epoch 11/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3129 - accuracy: 0.9107 - val_loss: 1.0355 - val_accuracy: 0.6632
# Epoch 12/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2995 - accuracy: 0.9254 - val_loss: 1.0419 - val_accuracy: 0.6632
# Epoch 13/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2954 - accuracy: 0.9287 - val_loss: 1.1130 - val_accuracy: 0.6812
# Epoch 14/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.3188 - accuracy: 0.8997 - val_loss: 1.0744 - val_accuracy: 0.6452
# Epoch 15/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.3035 - accuracy: 0.9235 - val_loss: 1.1067 - val_accuracy: 0.6735
# Epoch 16/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2986 - accuracy: 0.9280 - val_loss: 1.0790 - val_accuracy: 0.6838
# Epoch 17/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2985 - accuracy: 0.9229 - val_loss: 1.0767 - val_accuracy: 0.6555
# Epoch 18/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2938 - accuracy: 0.9332 - val_loss: 1.0789 - val_accuracy: 0.6787
# Epoch 19/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2967 - accuracy: 0.9254 - val_loss: 1.0971 - val_accuracy: 0.6787
# Epoch 20/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.3157 - accuracy: 0.9126 - val_loss: 1.0579 - val_accuracy: 0.6735
# Epoch 21/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2992 - accuracy: 0.9299 - val_loss: 1.0743 - val_accuracy: 0.6684
# Epoch 22/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2885 - accuracy: 0.9280 - val_loss: 1.0813 - val_accuracy: 0.6761
# Epoch 23/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2827 - accuracy: 0.9377 - val_loss: 1.0750 - val_accuracy: 0.6607
# Epoch 24/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2810 - accuracy: 0.9312 - val_loss: 1.0834 - val_accuracy: 0.6915
# Epoch 25/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2828 - accuracy: 0.9306 - val_loss: 1.0712 - val_accuracy: 0.6607
# Epoch 26/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2849 - accuracy: 0.9312 - val_loss: 1.0896 - val_accuracy: 0.6761
# Epoch 27/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2851 - accuracy: 0.9364 - val_loss: 1.0973 - val_accuracy: 0.6581
# Epoch 28/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2901 - accuracy: 0.9274 - val_loss: 1.0763 - val_accuracy: 0.6607
# Epoch 29/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2891 - accuracy: 0.9293 - val_loss: 1.0597 - val_accuracy: 0.6812
# Epoch 30/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2896 - accuracy: 0.9293 - val_loss: 1.0855 - val_accuracy: 0.6864
# Epoch 31/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2791 - accuracy: 0.9306 - val_loss: 1.0742 - val_accuracy: 0.6504
# Epoch 32/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2808 - accuracy: 0.9306 - val_loss: 1.0903 - val_accuracy: 0.6787
# Epoch 33/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2780 - accuracy: 0.9344 - val_loss: 1.0696 - val_accuracy: 0.6658
# Epoch 34/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2796 - accuracy: 0.9267 - val_loss: 1.0758 - val_accuracy: 0.6555
# Epoch 35/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2845 - accuracy: 0.9293 - val_loss: 1.0956 - val_accuracy: 0.6787
# Epoch 36/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2793 - accuracy: 0.9370 - val_loss: 1.0850 - val_accuracy: 0.6607
# Epoch 37/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2884 - accuracy: 0.9203 - val_loss: 1.0640 - val_accuracy: 0.6735
# Epoch 38/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.3010 - accuracy: 0.9216 - val_loss: 1.0783 - val_accuracy: 0.6555
# Epoch 39/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2809 - accuracy: 0.9319 - val_loss: 1.0876 - val_accuracy: 0.6607
# Epoch 40/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2762 - accuracy: 0.9293 - val_loss: 1.0794 - val_accuracy: 0.6427
# Epoch 41/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2882 - accuracy: 0.9222 - val_loss: 1.0828 - val_accuracy: 0.6838
# Epoch 42/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2912 - accuracy: 0.9203 - val_loss: 1.0662 - val_accuracy: 0.6684
# Epoch 43/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2840 - accuracy: 0.9299 - val_loss: 1.0667 - val_accuracy: 0.6761
# Epoch 44/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2828 - accuracy: 0.9325 - val_loss: 1.0907 - val_accuracy: 0.6478
# Epoch 45/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2820 - accuracy: 0.9325 - val_loss: 1.0614 - val_accuracy: 0.6632
# Epoch 46/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2737 - accuracy: 0.9306 - val_loss: 1.0780 - val_accuracy: 0.6761
# Epoch 47/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2747 - accuracy: 0.9338 - val_loss: 1.0714 - val_accuracy: 0.6452
# Epoch 48/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2761 - accuracy: 0.9357 - val_loss: 1.0808 - val_accuracy: 0.6710
# Epoch 49/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2707 - accuracy: 0.9357 - val_loss: 1.0660 - val_accuracy: 0.6787
# Epoch 50/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2718 - accuracy: 0.9344 - val_loss: 1.0697 - val_accuracy: 0.6452
# Epoch 51/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2646 - accuracy: 0.9396 - val_loss: 1.0873 - val_accuracy: 0.6761
# Epoch 52/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2672 - accuracy: 0.9383 - val_loss: 1.0757 - val_accuracy: 0.6710
# Epoch 53/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2684 - accuracy: 0.9377 - val_loss: 1.0775 - val_accuracy: 0.6787
# Epoch 54/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2728 - accuracy: 0.9351 - val_loss: 1.0698 - val_accuracy: 0.6607
# Epoch 55/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2791 - accuracy: 0.9287 - val_loss: 1.0707 - val_accuracy: 0.6632
# Epoch 56/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2881 - accuracy: 0.9325 - val_loss: 1.0747 - val_accuracy: 0.6967
# Epoch 57/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2895 - accuracy: 0.9306 - val_loss: 1.0848 - val_accuracy: 0.6504
# Epoch 58/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2793 - accuracy: 0.9306 - val_loss: 1.0708 - val_accuracy: 0.6787
# Epoch 59/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2785 - accuracy: 0.9338 - val_loss: 1.0679 - val_accuracy: 0.6607
# Epoch 60/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2770 - accuracy: 0.9319 - val_loss: 1.0859 - val_accuracy: 0.6787
# Epoch 61/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2722 - accuracy: 0.9357 - val_loss: 1.0908 - val_accuracy: 0.6710
# Epoch 62/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2677 - accuracy: 0.9396 - val_loss: 1.0630 - val_accuracy: 0.6504
# Epoch 63/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2731 - accuracy: 0.9332 - val_loss: 1.0834 - val_accuracy: 0.6812
# Epoch 64/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2728 - accuracy: 0.9299 - val_loss: 1.0736 - val_accuracy: 0.6555
# Epoch 65/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2865 - accuracy: 0.9216 - val_loss: 1.0675 - val_accuracy: 0.6684
# Epoch 66/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.3034 - accuracy: 0.9165 - val_loss: 1.0883 - val_accuracy: 0.6761
# Epoch 67/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2806 - accuracy: 0.9312 - val_loss: 1.0537 - val_accuracy: 0.6581
# Epoch 68/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2702 - accuracy: 0.9370 - val_loss: 1.0951 - val_accuracy: 0.6658
# Epoch 69/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2818 - accuracy: 0.9338 - val_loss: 1.0837 - val_accuracy: 0.6658
# Epoch 70/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2816 - accuracy: 0.9274 - val_loss: 1.0935 - val_accuracy: 0.6812
# Epoch 71/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2677 - accuracy: 0.9364 - val_loss: 1.0509 - val_accuracy: 0.6607
# Epoch 72/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2657 - accuracy: 0.9351 - val_loss: 1.1042 - val_accuracy: 0.6761
# Epoch 73/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2683 - accuracy: 0.9344 - val_loss: 1.0729 - val_accuracy: 0.6452
# Epoch 74/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2679 - accuracy: 0.9377 - val_loss: 1.0598 - val_accuracy: 0.6555
# Epoch 75/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2683 - accuracy: 0.9422 - val_loss: 1.0650 - val_accuracy: 0.6864
# Epoch 76/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2685 - accuracy: 0.9351 - val_loss: 1.0729 - val_accuracy: 0.6530
# Epoch 77/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2674 - accuracy: 0.9396 - val_loss: 1.0753 - val_accuracy: 0.6761
# Epoch 78/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2721 - accuracy: 0.9306 - val_loss: 1.0633 - val_accuracy: 0.6735
# Epoch 79/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2752 - accuracy: 0.9344 - val_loss: 1.0451 - val_accuracy: 0.6581
# Epoch 80/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2698 - accuracy: 0.9389 - val_loss: 1.1019 - val_accuracy: 0.6684
# Epoch 81/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2760 - accuracy: 0.9280 - val_loss: 1.0608 - val_accuracy: 0.6735
# Epoch 82/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2770 - accuracy: 0.9287 - val_loss: 1.0978 - val_accuracy: 0.6504
# Epoch 83/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2868 - accuracy: 0.9235 - val_loss: 1.0805 - val_accuracy: 0.6530
# Epoch 84/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2937 - accuracy: 0.9184 - val_loss: 1.1219 - val_accuracy: 0.6735
# Epoch 85/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2768 - accuracy: 0.9364 - val_loss: 1.0672 - val_accuracy: 0.6658
# Epoch 86/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2580 - accuracy: 0.9357 - val_loss: 1.0726 - val_accuracy: 0.6555
# Epoch 87/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2584 - accuracy: 0.9396 - val_loss: 1.0647 - val_accuracy: 0.6812
# Epoch 88/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2520 - accuracy: 0.9428 - val_loss: 1.0653 - val_accuracy: 0.6504
# Epoch 89/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2672 - accuracy: 0.9287 - val_loss: 1.0514 - val_accuracy: 0.6684
# Epoch 90/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2885 - accuracy: 0.9274 - val_loss: 1.0837 - val_accuracy: 0.6658
# Epoch 91/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2812 - accuracy: 0.9261 - val_loss: 1.0920 - val_accuracy: 0.6658
# Epoch 92/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2754 - accuracy: 0.9299 - val_loss: 1.0706 - val_accuracy: 0.6581
# Epoch 93/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2584 - accuracy: 0.9409 - val_loss: 1.0825 - val_accuracy: 0.6607
# Epoch 94/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2584 - accuracy: 0.9396 - val_loss: 1.0565 - val_accuracy: 0.6761
# Epoch 95/800
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2543 - accuracy: 0.9377 - val_loss: 1.0588 - val_accuracy: 0.6632
# Epoch 96/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2539 - accuracy: 0.9434 - val_loss: 1.0662 - val_accuracy: 0.6684
# Epoch 97/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2587 - accuracy: 0.9434 - val_loss: 1.0759 - val_accuracy: 0.6658
# Epoch 98/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2670 - accuracy: 0.9370 - val_loss: 1.1196 - val_accuracy: 0.6710
# Epoch 99/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2674 - accuracy: 0.9351 - val_loss: 1.0724 - val_accuracy: 0.6658
# Epoch 100/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2655 - accuracy: 0.9306 - val_loss: 1.0815 - val_accuracy: 0.6864
# Epoch 101/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2577 - accuracy: 0.9422 - val_loss: 1.1161 - val_accuracy: 0.6710
# Epoch 102/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2832 - accuracy: 0.9203 - val_loss: 1.1231 - val_accuracy: 0.6478
# Epoch 103/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3108 - accuracy: 0.9030 - val_loss: 1.0953 - val_accuracy: 0.6710
# Epoch 104/800
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2717 - accuracy: 0.9293 - val_loss: 1.0878 - val_accuracy: 0.6632
# Epoch 105/800
# 7/7 [==============================] - 0s 20ms/step - loss: 0.2642 - accuracy: 0.9357 - val_loss: 1.0673 - val_accuracy: 0.6530
# Epoch 106/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.3023 - accuracy: 0.9120 - val_loss: 1.1785 - val_accuracy: 0.6530
# Epoch 107/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2798 - accuracy: 0.9254 - val_loss: 1.1381 - val_accuracy: 0.6478
# Epoch 108/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2828 - accuracy: 0.9235 - val_loss: 1.1012 - val_accuracy: 0.6427
# Epoch 109/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2809 - accuracy: 0.9332 - val_loss: 1.0972 - val_accuracy: 0.6735
# Epoch 110/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2593 - accuracy: 0.9364 - val_loss: 1.0875 - val_accuracy: 0.6375
# Epoch 111/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2522 - accuracy: 0.9473 - val_loss: 1.0806 - val_accuracy: 0.6710
# Epoch 112/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2521 - accuracy: 0.9447 - val_loss: 1.0950 - val_accuracy: 0.6761
# Epoch 113/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2503 - accuracy: 0.9415 - val_loss: 1.0928 - val_accuracy: 0.6787
# Epoch 114/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2574 - accuracy: 0.9351 - val_loss: 1.0604 - val_accuracy: 0.6787
# Epoch 115/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2477 - accuracy: 0.9428 - val_loss: 1.0829 - val_accuracy: 0.6787
# Epoch 116/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2572 - accuracy: 0.9434 - val_loss: 1.0923 - val_accuracy: 0.6838
# Epoch 117/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2657 - accuracy: 0.9325 - val_loss: 1.0862 - val_accuracy: 0.6530
# Epoch 118/800
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2584 - accuracy: 0.9383 - val_loss: 1.0669 - val_accuracy: 0.6735
# Epoch 119/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2426 - accuracy: 0.9467 - val_loss: 1.0686 - val_accuracy: 0.6684
# Epoch 120/800
# 7/7 [==============================] - 0s 16ms/step - loss: 0.2410 - accuracy: 0.9486 - val_loss: 1.0888 - val_accuracy: 0.6710
# Epoch 121/800
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2447 - accuracy: 0.9460 - val_loss: 1.0715 - val_accuracy: 0.6864
# Epoch 122/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2597 - accuracy: 0.9319 - val_loss: 1.0641 - val_accuracy: 0.6658
# Epoch 123/800
# 7/7 [==============================] - 0s 24ms/step - loss: 0.2456 - accuracy: 0.9402 - val_loss: 1.1012 - val_accuracy: 0.6864
# Epoch 124/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2555 - accuracy: 0.9351 - val_loss: 1.0763 - val_accuracy: 0.6735
# Epoch 125/800
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2508 - accuracy: 0.9415 - val_loss: 1.0752 - val_accuracy: 0.6581
# Epoch 126/800
# 7/7 [==============================] - 0s 18ms/step - loss: 0.2424 - accuracy: 0.9454 - val_loss: 1.0884 - val_accuracy: 0.6787
# Epoch 127/800
# 7/7 [==============================] - 0s 17ms/step - loss: 0.2551 - accuracy: 0.9454 - val_loss: 1.0779 - val_accuracy: 0.6710
# Epoch 128/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2583 - accuracy: 0.9396 - val_loss: 1.0862 - val_accuracy: 0.6735
# Epoch 129/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2451 - accuracy: 0.9460 - val_loss: 1.0968 - val_accuracy: 0.6504
# Epoch 130/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2558 - accuracy: 0.9370 - val_loss: 1.1283 - val_accuracy: 0.6735
# Epoch 131/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2520 - accuracy: 0.9351 - val_loss: 1.0960 - val_accuracy: 0.6658
# Epoch 132/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2455 - accuracy: 0.9402 - val_loss: 1.0752 - val_accuracy: 0.6632
# Epoch 133/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2461 - accuracy: 0.9460 - val_loss: 1.0826 - val_accuracy: 0.6710
# Epoch 134/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2487 - accuracy: 0.9351 - val_loss: 1.0723 - val_accuracy: 0.6684
# Epoch 135/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2434 - accuracy: 0.9454 - val_loss: 1.0689 - val_accuracy: 0.6761
# Epoch 136/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2384 - accuracy: 0.9467 - val_loss: 1.0728 - val_accuracy: 0.6710
# Epoch 137/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2484 - accuracy: 0.9389 - val_loss: 1.0754 - val_accuracy: 0.6581
# Epoch 138/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2499 - accuracy: 0.9473 - val_loss: 1.0761 - val_accuracy: 0.6915
# Epoch 139/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2392 - accuracy: 0.9428 - val_loss: 1.0683 - val_accuracy: 0.6710
# Epoch 140/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2371 - accuracy: 0.9460 - val_loss: 1.0815 - val_accuracy: 0.6915
# Epoch 141/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2337 - accuracy: 0.9467 - val_loss: 1.0676 - val_accuracy: 0.6735
# Epoch 142/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2444 - accuracy: 0.9434 - val_loss: 1.0639 - val_accuracy: 0.6684
# Epoch 143/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2444 - accuracy: 0.9434 - val_loss: 1.0728 - val_accuracy: 0.6787
# Epoch 144/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2467 - accuracy: 0.9434 - val_loss: 1.0691 - val_accuracy: 0.6710
# Epoch 145/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2404 - accuracy: 0.9492 - val_loss: 1.0874 - val_accuracy: 0.6761
# Epoch 146/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2453 - accuracy: 0.9454 - val_loss: 1.0999 - val_accuracy: 0.6889
# Epoch 147/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2573 - accuracy: 0.9338 - val_loss: 1.0884 - val_accuracy: 0.6530
# Epoch 148/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2497 - accuracy: 0.9402 - val_loss: 1.1115 - val_accuracy: 0.6761
# Epoch 149/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2423 - accuracy: 0.9396 - val_loss: 1.0817 - val_accuracy: 0.6530
# Epoch 150/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2376 - accuracy: 0.9512 - val_loss: 1.0693 - val_accuracy: 0.6864
# Epoch 151/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2386 - accuracy: 0.9460 - val_loss: 1.0780 - val_accuracy: 0.6812
# Epoch 152/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2389 - accuracy: 0.9434 - val_loss: 1.0622 - val_accuracy: 0.6607
# Epoch 153/800
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2323 - accuracy: 0.9460 - val_loss: 1.0807 - val_accuracy: 0.6684
# Epoch 154/800
# 7/7 [==============================] - 0s 15ms/step - loss: 0.2294 - accuracy: 0.9531 - val_loss: 1.0702 - val_accuracy: 0.6761
# Epoch 155/800
# 7/7 [==============================] - 0s 14ms/step - loss: 0.2248 - accuracy: 0.9505 - val_loss: 1.0548 - val_accuracy: 0.6761
# Epoch 156/800
# 7/7 [==============================] - 0s 10ms/step - loss: 0.2231 - accuracy: 0.9473 - val_loss: 1.0632 - val_accuracy: 0.6735
# Epoch 157/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2268 - accuracy: 0.9512 - val_loss: 1.0933 - val_accuracy: 0.6812
# Epoch 158/800
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2257 - accuracy: 0.9454 - val_loss: 1.0924 - val_accuracy: 0.6658
# Epoch 159/800
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2432 - accuracy: 0.9479 - val_loss: 1.0880 - val_accuracy: 0.6761
# Epoch 160/800
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2490 - accuracy: 0.9325 - val_loss: 1.0852 - val_accuracy: 0.6710
# Epoch 161/800
# 1/7 [===>..........................] - ETA: 0s - loss: 0.2449 - accuracy: 0.9453Restoring model weights from the end of the best epoch: 11.
# 7/7 [==============================] - 0s 13ms/step - loss: 0.2382 - accuracy: 0.9428 - val_loss: 1.0627 - val_accuracy: 0.6555
# Epoch 161: early stopping
# 61/61 [==============================] - 0s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
#predict for testing data and printout the accuracy
train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
print(f'train Accuracy: {train_accuracy}')
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f'Test Accuracy: {test_accuracy}')
# Out:
# train Accuracy: 0.8760925531387329
# Test Accuracy: 0.6303901672363281

# %% [markdown]
# Now comes the learning part :)\
# Here's a new thing. Print the classification report of your predictions.

# %%
#print the classification report for the model
from sklearn.metrics import classification_report
import numpy as np

# Assuming y_pred and y_test are your predicted and actual labels respectively

# Convert one-hot encoded predictions back to labels if necessary
y_pred_labels = np.argmax(test_predict, axis=1)

# Decode labels if necessary (inverse of label encoding)
decoded_y_pred_labels = label_encoder.inverse_transform(y_pred_labels)
decoded_y_test_labels = label_encoder.inverse_transform(np.argmax(y_test, axis=1))

# Print classification report
print(classification_report(decoded_y_test_labels, decoded_y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.60      0.47      0.53        38
#            2       0.79      0.69      0.73        86
#            3       0.62      0.56      0.59        68
#            4       0.54      0.69      0.61        78
#            5       0.74      0.87      0.80        68
#            6       0.52      0.49      0.50        69
#            7       0.61      0.56      0.58        41
#            8       0.59      0.56      0.58        39
#
#     accuracy                           0.63       487
#    macro avg       0.63      0.61      0.62       487
# weighted avg       0.63      0.63      0.63       487

# %% [markdown]
# Just for fun. You can explore on callbacks used in model.fit().\
# For resources, you can go to https://keras.io/api/callbacks/ and explore on your own. Or just chatgpt :)
# Now try the model using EarlyStopping callback, LearningRateScheduler callback and ModelCheckpoint callback.

# %%
#Have fun ..... you just completed the project

# %% [markdown]
# The timeline for this is 2 weeks. In the last two weeks, we will be exploring further concepts in AIML or doing some fun activities in the field. Look forward to it :)
